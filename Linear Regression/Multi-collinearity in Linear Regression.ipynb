# %%
import pandas as pd
import numpy as np
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv(r'C:\Users\Rishabh\Documents\IMS Proschool Data Science\Linear Regression\Advertising.csv')
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
X = df[['TV','Radio','Newspaper']]
y = df.Sales

# %%
import statsmodels.api as sm

# %%
# Fit an OLS(Ordinary Least Square) model with intercept on TV and Radio
X = sm.add_constant(X)
model = sm.OLS(y,X).fit()

# %%
X
# Out:
#      const     TV  Radio  Newspaper
# 0      1.0  230.1   37.8       69.2
# 1      1.0   44.5   39.3       45.1
# 2      1.0   17.2   45.9       69.3
# 3      1.0  151.5   41.3       58.5
# 4      1.0  180.8   10.8       58.4
# ..     ...    ...    ...        ...
# 195    1.0   38.2    3.7       13.8
# 196    1.0   94.2    4.9        8.1
# 197    1.0  177.0    9.3        6.4
# 198    1.0  283.6   42.0       66.2
# 199    1.0  232.1    8.6        8.7
#
# [200 rows x 4 columns]

# %% [markdown]
# This constant value is for the intercept that is present in the equation so that the intercept value is calculated and it is being multiplied by this constant value of 1.

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     570.3
# Date:                Tue, 14 Apr 2020   Prob (F-statistic):           1.58e-96
# Time:                        21:43:06   Log-Likelihood:                -386.18
# No. Observations:                 200   AIC:                             780.4
# Df Residuals:                     196   BIC:                             793.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.9389      0.312      9.422      0.000       2.324       3.554
# ...

# %%
X.iloc[:,1:].corr()
# Out:
#                  TV     Radio  Newspaper
# TV         1.000000  0.054809   0.056648
# Radio      0.054809  1.000000   0.354104
# Newspaper  0.056648  0.354104   1.000000
